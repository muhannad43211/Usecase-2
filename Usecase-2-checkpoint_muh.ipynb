# %%
#Import all relevant libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from scipy.stats import zscore

## This statement allows the visuals to render within your Jupyter Notebook.
# %matplotlib inline

# %% [markdown]
# ## Loading the data
# We can now load the dataset into pandas using the read_csv() function. This converts the CSV file into a Pandas dataframe.

# %%
#Read in the csv file and convert to a Pandas dataframe
df_15 = pd.read_csv("2015.csv")#read the World Happiness file for year 2015
df_16 = pd.read_csv("2016.csv")#read the World Happiness file for year 2016
df_17 = pd.read_csv("2017.csv")#read the World Happiness file for year 2017
df_18 = pd.read_csv("2018.csv")#read the World Happiness file for year 2018
df_19 = pd.read_csv("2019.csv")#read the World Happiness file for year 2019

# %% [markdown]
# ### Viewing the dataframe
# We can get a quick sense of the size of our dataset by using the shape method. This returns a tuple with the number of rows and columns in the dataset.

# %%
df_15.head() #View the top five in the data frame in 2015
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_16.head() #View the top five in the data frame in 2016
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_17.head() #View the top five in the dataset in 2017
# Out:
#        Country          Region  Happiness Rank  Happiness Score  Whisker.high  \
# 0       Norway  Western Europe               1            7.537      7.594445
# 1      Denmark  Western Europe               2            7.522      7.581728
# 2      Iceland  Western Europe               3            7.504      7.622030
# 3  Switzerland  Western Europe               4            7.494      7.561772
# 4      Finland  Western Europe               5            7.469      7.527542
#
#    Whisker.low  Economy (GDP per Capita)    Family  Health (Life Expectancy)  \
# 0     7.479556                  1.616463  1.533524                  0.796667
# 1     7.462272                  1.482383  1.551122                  0.792566
# 2     7.385970                  1.480633  1.610574                  0.833552
# 3     7.426227                  1.564980  1.516912                  0.858131
# 4     7.410458                  1.443572  1.540247                  0.809158
#
# ...

# %%
df_18.head() #View the top five in the dataset in 2018
# Out:
#    Happiness Rank      Country          Region  Happiness Score  \
# 0               1      Finland  Western Europe            7.632
# 1               2       Norway  Western Europe            7.594
# 2               3      Denmark  Western Europe            7.555
# 3               4      Iceland  Western Europe            7.495
# 4               5  Switzerland  Western Europe            7.487
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.305           1.592                    0.874
# 1           1.456           1.582                    0.861
# 2           1.351           1.590                    0.868
# 3           1.343           1.644                    0.914
# 4           1.420           1.549                    0.927
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.681       0.202                      0.393
# 1                         0.686       0.286                      0.340
# ...

# %%
df_19.head() #View the top five in the dataset in 2019
# Out:
#    Happiness Rank      Country          Region  Happiness Score  \
# 0               1      Finland  Western Europe            7.769
# 1               2      Denmark  Western Europe            7.600
# 2               3       Norway  Western Europe            7.554
# 3               4      Iceland  Western Europe            7.494
# 4               5  Netherlands  Western Europe            7.488
#
#    GDP per capita  Social support  Healthy life expectancy  \
# 0           1.340           1.587                    0.986
# 1           1.383           1.573                    0.996
# 2           1.488           1.582                    1.028
# 3           1.380           1.624                    1.026
# 4           1.396           1.522                    0.999
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.596       0.153                      0.393
# 1                         0.592       0.252                      0.410
# ...

# %%
df_15.shape #number of rows and columns in the dataset in 2015
# Out:
# (158, 12)

# %%
df_16.shape #number of rows and columns in the dataset in 2016 In this dataset the number of columns is more than 2015 and 2017
# Out:
# (157, 13)

# %%
df_17.shape #number of rows and columns in the dataset in 2017
# Out:
# (155, 12)

# %%
df_18.shape #number of rows and columns in the dataset in 2018
# Out:
# (156, 9)

# %%
df_19.shape #number of rows and columns in the dataset in 2019
# Out:
# (156, 9)

# %% [markdown]
# ## 1. Data Profiling:
# Data profiling is a comprehensive process of examining the data available in an existing dataset and collecting statistics and information about that data.

# %%
df_15.info() #Columns with numeric values datatype float and int in 2015
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df_16.info() #Columns with numeric values datatype float and int in 2016
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
df_17.info() ##Columns with numeric values datatype float and int in 2017
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness.Rank                 155 non-null    int64
#  2   Happiness.Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Economy..GDP.per.Capita.       155 non-null    float64
#  6   Family                         155 non-null    float64
#  7   Health..Life.Expectancy.       155 non-null    float64
#  8   Freedom                        155 non-null    float64
#  9   Generosity                     155 non-null    float64
#  10  Trust..Government.Corruption.  155 non-null    float64
#  11  Dystopia.Residual              155 non-null    float64
# ...

# %%
df_18.info() #Columns with numeric values datatype float and int in 2018
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df_19.info() #Columns with numeric values datatype float and int in 2019
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
df_15.describe() #view the count, mean, std, min, 25%, 50%, 75% and the max for each column in 2015
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df_16.describe() #view the count, mean, std, min, 25%, 50%, 75% and the max for each column in 2016
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
df_17.describe() #view the count, mean, std, min, 25%, 50%, 75% and the max for each column in 2017
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %%
df_18.describe() #view the count, mean, std, min, 25%, 50%, 75% and the max for each column in 2018
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.375917        0.891449        1.213237
# std       45.177428    1.119506        0.391921        0.302372
# min        1.000000    2.905000        0.000000        0.000000
# 25%       39.750000    4.453750        0.616250        1.066750
# 50%       78.500000    5.378000        0.949500        1.255000
# 75%      117.250000    6.168500        1.197750        1.463000
# max      156.000000    7.632000        2.096000        1.644000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.597346                      0.454506    0.181006
# std                   0.247579                      0.162424    0.098471
# min                   0.000000                      0.000000    0.000000
# ...

# %%
df_19.describe() #view the count, mean, std, min, 25%, 50%, 75% and the max for each column in 2019
# Out:
#        Overall rank       Score  GDP per capita  Social support  \
# count    156.000000  156.000000      156.000000      156.000000
# mean      78.500000    5.407096        0.905147        1.208814
# std       45.177428    1.113120        0.398389        0.299191
# min        1.000000    2.853000        0.000000        0.000000
# 25%       39.750000    4.544500        0.602750        1.055750
# 50%       78.500000    5.379500        0.960000        1.271500
# 75%      117.250000    6.184500        1.232500        1.452500
# max      156.000000    7.769000        1.684000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               156.000000                    156.000000  156.000000
# mean                  0.725244                      0.392571    0.184846
# std                   0.242124                      0.143289    0.095254
# min                   0.000000                      0.000000    0.000000
# ...

# %% [markdown]
# The process of profiling differs slightly for categorical and numerical variables due to their inherent differences.
#
# **The two main types of data are:**
# - Quantitative (numerical) data
# - Qualitative (categorical) data

# %% [markdown]
# ### Data Quality Checks
# Data quality checks involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable.
#
#
# **Here are typical steps involved in checking data quality:**

# %% [markdown]
# #### 1. Reliability:
# Evaluate the data's source and collection process to determine its trustworthiness.

# %%
#it is Reliable from gallup world poll

# %% [markdown]
# #### 2. Timeliness:
# Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis.

# %% [markdown]
# #### 3. Consistency:
#
# Confirm that the data is consistent within the dataset and across multiple data sources. For example, the same data point should not have different values in different places.

# %%
#It is consistent and non-inconsistent data

# %% [markdown]
# #### 4. Relevance:
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.
#
# **Key considerations for relevance include:**
#
# > 1. Sample Appropriateness: Confirm that your data sample aligns with your analysis objectives. For instance, utilizing data from the Northern region will not yield accurate insights for the Western region of the Kingdom.
# >
# > 2. Variable Selection: Any column will not be relevant for our analysis, we can get rid of these using the drop() method. We will set the “axis” argument to 1 since we’re dealing with columns, and set the “inplace” argument to True to make the change permanent.

# %%
#In 2015, data were taken from 158 countries, in 2016 from 157 countries, and in 2017 from 155 countries ,in 2018,2019 from 156 countris.

# %% [markdown]
# #### 5. Uniqueness:
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
df_15.duplicated().sum() #no duplicates values in 2015
# Out:
# 0

# %%
df_16.duplicated().sum() #no duplicates values in 2016
# Out:
# 0

# %%
df_17.duplicated().sum() #no duplicates values in 2017
# Out:
# 0

# %%
df_18.duplicated().sum() #no duplicates values in 2018
# Out:
# 0

# %%
df_19.duplicated().sum() #no duplicates values in 2019
# Out:
# 0

# %%
#no duplicates

# %% [markdown]
# #### 6. Completeness:
# Ensure that no critical data is missing. This might mean checking for null values or required fields that are empty.
#
# We will start by checking the dataset for missing or null values. For this, we can use the isna() method which returns a dataframe of boolean values indicating if a field is null or not. To group all missing values by column, we can include the sum() method.

# %%
#Display number missing values per column

# %%
df_15.isnull().sum() #Display number missing values in 2015 # no missing values
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df_16.isnull().sum() #Display number missing values in 2016 #no missing values
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df_17.isnull().sum() #Display number missing values in 2017 #no missing values
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %%
df_18.isnull().sum() #there is one missing value
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %%
df_18[df_18['Perceptions of corruption'].isnull()] # will handle the missing value with the mean for the years 2015, 2016, 2017 and 2019.
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 19            20  United Arab Emirates  6.774           2.096           0.776
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 19                     0.67                         0.284       0.186
#
#     Perceptions of corruption
# 19                        NaN

# %%
number = [0.38583, 0.35561, 0.324490, 0.182]
total = sum(number)
count = len(number)
n = total / count
print(n)
# Out:
# 0.3119825

# %%
df_18["Perceptions of corruption"].fillna(0.3119,inplace=True)

# %%
df_19.isnull().sum() # no missing values in 2019
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# #### 7. Check Accuracy:
#
# Verify that the data is correct and precise. This could involve comparing data samples with known sources or using validation rules.
#
# **The process includes:**
# 1. Validating the appropriateness of data types for the dataset.
# 2. Identifying outliers  using established validation  rule

# %%
# check columns types

# %%
df_19.rename(columns={'Overall rank': 'Happiness Rank'}, inplace=True)

# %%
df_19.rename(columns={'Score': 'Happiness Score'}, inplace=True)

# %%
df_17.rename(columns={'Health..Life.Expectancy.': 'Health (Life Expectancy)'}, inplace=True)

# %%
df_17.rename(columns={'Trust..Government.Corruption.': 'Trust (Government Corruption)'}, inplace=True)

# %%
df_17.rename(columns={'Dystopia.Residual': 'Dystopia Residual'}, inplace=True)

# %%
df_17.rename(columns={'Economy..GDP.per.Capita.': 'Economy (GDP per Capita)'}, inplace=True)

# %%
df_18.rename(columns={'Country or region': 'Country'}, inplace=True)

# %%
df_19.rename(columns={'Country or region': 'Country'}, inplace=True)

# %%
df_17['Region'] = df_17['Country'].map(df_15.set_index('Country')['Region'])

# %%
df_18['Region'] = df_18['Country'].map(df_15.set_index('Country')['Region'])

# %%
df_19['Region'] = df_19['Country'].map(df_15.set_index('Country')['Region'])

# %%
cols = list(df_17.columns)  # Get current column names as a list
cols.insert(1, cols.pop(cols.index('Region')))  
df_17 = df_17[cols]

# %%
cols = list(df_18.columns)  # Get current column names as a list
cols.insert(2, cols.pop(cols.index('Region')))  
df_18 = df_18[cols]

# %%
cols = list(df_19.columns)  # Get current column names as a list
cols.insert(2, cols.pop(cols.index('Region')))  
df_19 = df_19[cols]

# %%
df_17.head()
# Out:
#        Country          Region  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0       Norway  Western Europe               1            7.537      7.594445
# 1      Denmark  Western Europe               2            7.522      7.581728
# 2      Iceland  Western Europe               3            7.504      7.622030
# 3  Switzerland  Western Europe               4            7.494      7.561772
# 4      Finland  Western Europe               5            7.469      7.527542
#
#    Whisker.low  Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.  \
# 0     7.479556                  1.616463  1.533524                  0.796667
# 1     7.462272                  1.482383  1.551122                  0.792566
# 2     7.385970                  1.480633  1.610574                  0.833552
# 3     7.426227                  1.564980  1.516912                  0.858131
# 4     7.410458                  1.443572  1.540247                  0.809158
#
# ...

# %%
df_18.head()
# Out:
#    Overall rank      Country          Region  Score  GDP per capita  \
# 0             1      Finland  Western Europe  7.632           1.305
# 1             2       Norway  Western Europe  7.594           1.456
# 2             3      Denmark  Western Europe  7.555           1.351
# 3             4      Iceland  Western Europe  7.495           1.343
# 4             5  Switzerland  Western Europe  7.487           1.420
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.592                    0.874                         0.681
# 1           1.582                    0.861                         0.686
# 2           1.590                    0.868                         0.683
# 3           1.644                    0.914                         0.677
# 4           1.549                    0.927                         0.660
#
#    Generosity  Perceptions of corruption
# 0       0.202                      0.393
# ...

# %%
df_19.head()
# Out:
#    Overall rank      Country          Region  Score  GDP per capita  \
# 0             1      Finland  Western Europe  7.769           1.340
# 1             2      Denmark  Western Europe  7.600           1.383
# 2             3       Norway  Western Europe  7.554           1.488
# 3             4      Iceland  Western Europe  7.494           1.380
# 4             5  Netherlands  Western Europe  7.488           1.396
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           1.587                    0.986                         0.596
# 1           1.573                    0.996                         0.592
# 2           1.582                    1.028                         0.603
# 3           1.624                    1.026                         0.591
# 4           1.522                    0.999                         0.557
#
#    Generosity  Perceptions of corruption
# 0       0.153                      0.393
# ...

# %%
# go to clean them

# %%
# check outliers

# %%
selected_columns = [
    'Happiness Rank', 
    'Happiness Score', 
    'Standard Error', 
    'Economy (GDP per Capita)', 
    'Family', 
    'Health (Life Expectancy)', 
    'Freedom', 
    'Trust (Government Corruption)', 
    'Generosity', 
    'Dystopia Residual'
]

# Create a boxplot using Plotly for the selected columns
fig = px.box(df_15, 
             y=selected_columns, 
             title='Boxplot for the World Happiness 2015')

fig.update_layout(
    yaxis_title='Values',
    xaxis_title='Columns',
)

fig.show()

# %%
selected_columns = [
    'Happiness Rank', 
    'Happiness Score',  
    'Economy (GDP per Capita)', 
    'Family', 
    'Health (Life Expectancy)', 
    'Freedom', 
    'Trust (Government Corruption)', 
    'Generosity', 
    'Dystopia Residual'
]

# Create a boxplot using Plotly for the selected columns
fig = px.box(df_16, 
             y=selected_columns, 
             title='Boxplot for the World Happiness 2016')

fig.update_layout(
    yaxis_title='Values',
    xaxis_title='Columns',
)

fig.show()

# %%
selected_columns = [
    'Happiness Rank', 
    'Happiness Score',  
    'Economy (GDP per Capita)', 
    'Family', 
    'Health (Life Expectancy)', 
    'Freedom', 
    'Trust (Government Corruption)', 
    'Generosity', 
    'Dystopia Residual'
]

# Create a boxplot using Plotly for the selected columns
fig = px.box(df_17, 
             y=selected_columns, 
             title='Boxplot for the World Happiness 2017')

fig.update_layout(
    yaxis_title='Values',
    xaxis_title='Columns',
)

fig.show()

# %%
selected_columns = [
    'Happiness Rank', 
    'Happiness Score',  
    'GDP per capita', 
    'Social support', 
    'Healthy life expectancy', 
    'Freedom to make life choices', 
    'Generosity',  
    'Perceptions of corruption'
]

# Create a boxplot using Plotly for the selected columns
fig = px.box(df_18, 
             y=selected_columns, 
             title='Boxplot for the World Happiness 2018')

fig.update_layout(
    yaxis_title='Values',
    xaxis_title='Columns',
)

fig.show()

# %%
selected_columns = [
    'Happiness Rank', 
    'Happiness Score',  
    'GDP per capita', 
    'Social support', 
    'Healthy life expectancy', 
    'Freedom to make life choices', 
    'Generosity',  
    'Perceptions of corruption'
]

# Create a boxplot using Plotly for the selected columns
fig = px.box(df_19, 
             y=selected_columns, 
             title='Boxplot for the World Happiness 2019')

fig.update_layout(
    yaxis_title='Values',
    xaxis_title='Columns',
)

fig.show()

# %% [markdown]
# **What is an Outlier?**
# Outlier is an row/observation that appears far away and diverges from an overall pattern in a sample.
#
# **What are the types of Outliers?**
# 1. Univariate: These outliers can be found when we look at distribution of a single variable
# 2. Multivariate: are outliers in an n-dimensional space. In order to find them, you have to look at distributions in multi-dimensions. example (hight=100, weight=100) for a person
#
# **What causes Outliers?**
# Whenever we come across outliers, the ideal way to tackle them is to find out the reason of having these outliers. The method to deal with them would then depend on the reason of their occurrence.
#
# Let’s understand various types of outliers:
#
# 1. Data Entry Errors:- Human errors such as errors caused during data collection, recording, or entry can cause outliers in data.
# 2. Measurement Error: It is the most common source of outliers. This is caused when the measurement instrument used turns out to be faulty.
# 3. Data Processing Error: Whenever we perform data mining, we extract data from multiple sources. It is possible that some manipulation or extraction errors may lead to outliers in the dataset.
# 4. Sampling error: For instance, we have to measure the height of athletes. By mistake, we include a few basketball players in the sample. This inclusion is likely to cause outliers in the dataset.
# 5. Natural Outlier: When an outlier is not artificial (due to error), it is a natural outlier. For instance: In my last assignment with one of the renowned insurance company, I noticed that the performance of top 50 financial advisors was far higher than rest of the population. Surprisingly, it was not due to any error. Hence, whenever we perform any data mining activity with advisors, we used to treat this segment separately.
#
#
# **What is the impact of Outliers on a dataset?**
#
#
# ![image.png](https://www.analyticsvidhya.com/wp-content/uploads/2015/02/Outlier_31.png)
#
#
#
# **How to detect Outliers?**
#
# 1. Most commonly used method to detect outliers is visualization (Univariate Graphical Analysis).
#
# We use 3 common visualization methods:
# >- Box-plot: A box plot is a method for graphically depicting groups of numerical data through their quartiles. The box extends from the Q1 to Q3 quartile values of the data, with a line at the median (Q2). The whiskers extend from the edges of the box to show the range of the data. Outlier points are those past the end of the whiskers. Box plots show robust measures of location and spread as well as providing information about symmetry and outliers.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:698/format:webp/1*VK5iHA2AB28HSZwWwUbNYg.png)
# >
# >
# >- Histogram
# >- Scatter Plot: A scatter plot is a mathematical diagram using Cartesian coordinates to display values for two variables for a set of data. The data are displayed as a collection of points, each having the value of one variable determining the position on the horizontal axis and the value of the other variable determining the position on the vertical axis. The points that are far from the population can be termed as an outlier.
# >
# >
# >![image.png](https://miro.medium.com/v2/resize:fit:4800/format:webp/1*Ov6aH-8yIwNoUxtMFwgx4g.png)
# >
# >
#
# 2. Using statistical method (Univariate Non-Graphical analysis):
# >- Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
#
# ![image.png](https://www.whatissixsigma.net/wp-content/uploads/2015/07/Box-Plot-Diagram-to-identify-Outliers-figure-1.png)
#
# >- Use capping methods. Any value which out of range of 5th and 95th percentile can be considered as outlier
# >- Data points, three or more standard deviation away from mean are considered outlier: The Z-score is the signed number of standard deviations by which the value of an observation or data point is above the mean value of what is being observed or measured. While calculating the Z-score we re-scale and center the data and look for data points that are too far from zero. These data points which are way too far from zero will be treated as the outliers. In most of the cases, a threshold of 3 or -3 is used i.e if the Z-score value is greater than or less than 3 or -3 respectively, that data point will be identified as outliers.
# > - Outlier detection is merely a special case of the examination of data for influential data points and it also depends on the business understanding

# %% [markdown]
# 1:What countries or regions rank the highest in overall happiness and each of the six factors contributing to happiness?

# %%
# Finding the top countries for each factor
top_countries = df_15.nlargest(10, 'Happiness Score')

# Create a bar chart for overall happiness score
fig = go.Figure()

fig.add_trace(go.Bar(
    x=top_countries['Country'],
    y=top_countries['Happiness Score'],
    name='Happiness Score',
    marker_color='blue'
))

for factor in ['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 
               'Freedom', 'Trust (Government Corruption)', 'Generosity']:
    fig.add_trace(go.Bar(
        x=top_countries['Country'],
        y=top_countries[factor],
        name=factor,
        marker_color=px.colors.qualitative.Set2[len(fig.data) % len(px.colors.qualitative.Set2)]
    ))

fig.update_layout(
    title='Top Countries in Happiness and Contributing Factors 2015',
    barmode='group',
    xaxis_title='Country',
    yaxis_title='Score',
    legend_title='Factors'
)

fig.show()

# %%
# Finding the top countries for each factor
top_countries = df_16.nlargest(10, 'Happiness Score')

# Create a bar chart for overall happiness score
fig = go.Figure()

fig.add_trace(go.Bar(
    x=top_countries['Country'],
    y=top_countries['Happiness Score'],
    name='Happiness Score',
    marker_color='blue'
))

for factor in ['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 
               'Freedom', 'Trust (Government Corruption)', 'Generosity']:
    fig.add_trace(go.Bar(
        x=top_countries['Country'],
        y=top_countries[factor],
        name=factor,
        marker_color=px.colors.qualitative.Set2[len(fig.data) % len(px.colors.qualitative.Set2)]
    ))

fig.update_layout(
    title='Top Countries in Happiness and Contributing Factors 2016',
    barmode='group',
    xaxis_title='Country',
    yaxis_title='Score',
    legend_title='Factors'
)

fig.show()

# %%
# Finding the top countries for each factor
top_countries = df_17.nlargest(10, 'Happiness Score')

# Create a bar chart for overall happiness score
fig = go.Figure()

fig.add_trace(go.Bar(
    x=top_countries['Country'],
    y=top_countries['Happiness Score'],
    name='Happiness Score',
    marker_color='blue'
))

for factor in ['Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 
               'Freedom', 'Trust (Government Corruption)', 'Generosity']:
    fig.add_trace(go.Bar(
        x=top_countries['Country'],
        y=top_countries[factor],
        name=factor,
        marker_color=px.colors.qualitative.Set2[len(fig.data) % len(px.colors.qualitative.Set2)]
    ))

fig.update_layout(
    title='Top Countries in Happiness and Contributing Factors 2017',
    barmode='group',
    xaxis_title='Country',
    yaxis_title='Score',
    legend_title='Factors'
)

fig.show()

# %%
# Finding the top countries for each factor
top_countries = df_18.nlargest(10, 'Happiness Score')

# Create a bar chart for overall happiness score
fig = go.Figure()

fig.add_trace(go.Bar(
    x=top_countries['Country'],
    y=top_countries['Happiness Score'],
    name='Happiness Score',
    marker_color='blue'
))

for factor in ['GDP per capita', 'Social support', 'Healthy life expectancy', 
               'Freedom to make life choices', 'Perceptions of corruption', 'Generosity']:
    fig.add_trace(go.Bar(
        x=top_countries['Country'],
        y=top_countries[factor],
        name=factor,
        marker_color=px.colors.qualitative.Set2[len(fig.data) % len(px.colors.qualitative.Set2)]
    ))

fig.update_layout(
    title='Top Countries in Happiness and Contributing Factors 2018',
    barmode='group',
    xaxis_title='Country',
    yaxis_title='Score',
    legend_title='Factors'
)

fig.show()

# %%
# Finding the top countries for each factor
top_countries = df_19.nlargest(10, 'Happiness Score')

# Create a bar chart for overall happiness score
fig = go.Figure()

fig.add_trace(go.Bar(
    x=top_countries['Country'],
    y=top_countries['Happiness Score'],
    name='Happiness Score',
    marker_color='blue'
))

for factor in ['GDP per capita', 'Social support', 'Healthy life expectancy', 
               'Freedom to make life choices', 'Perceptions of corruption', 'Generosity']:
    fig.add_trace(go.Bar(
        x=top_countries['Country'],
        y=top_countries[factor],
        name=factor,
        marker_color=px.colors.qualitative.Set2[len(fig.data) % len(px.colors.qualitative.Set2)]
    ))

fig.update_layout(
    title='Top Countries in Happiness and Contributing Factors 2019',
    barmode='group',
    xaxis_title='Country',
    yaxis_title='Score',
    legend_title='Factors'
)

fig.show()

# %% [markdown]
# 2:How did country ranks or scores change between the 2015 and 2016 as well as the 2016 and 2017 reports?

# %%
merged_df = pd.merge(df_15, df_16, on='Country', suffixes=('_2015', '_2016'))


merged_df['Rank Change'] = merged_df['Happiness Rank_2015'] - merged_df['Happiness Rank_2016']
merged_df['Score Change'] = merged_df['Happiness Score_2016'] - merged_df['Happiness Score_2015']
fig = px.scatter(merged_df, 
                 x='Happiness Score_2015', 
                 y='Happiness Score_2016',
                 color='Country',
                 title='Happiness Score Change from 2015 to 2016',
                 labels={
                     'Happiness Score_2015': 'Happiness Score (2015)',
                     'Happiness Score_2016': 'Happiness Score (2016)'
                 })


fig.add_shape(type='line', x0=min(merged_df['Happiness Score_2015']), x1=max(merged_df['Happiness Score_2015']),
              y0=min(merged_df['Happiness Score_2015']), y1=max(merged_df['Happiness Score_2015']),
              line=dict(color='Red', dash='dash'))
fig.show()

# %%
merged_df = pd.merge(df_16, df_17, on='Country', suffixes=('_2016', '_2017'))


merged_df['Rank Change'] = merged_df['Happiness Rank_2016'] - merged_df['Happiness Rank_2017']
merged_df['Score Change'] = merged_df['Happiness Score_2017'] - merged_df['Happiness Score_2016']
fig = px.scatter(merged_df, 
                 x='Happiness Score_2016', 
                 y='Happiness Score_2017',
                 color='Country',
                 title='Happiness Score Change from 2016 to 2017',
                 labels={
                     'Happiness Score_2016': 'Happiness Score (2016)',
                     'Happiness Score_2017': 'Happiness Score (2017)'
                 })


fig.add_shape(type='line', x0=min(merged_df['Happiness Score_2016']), x1=max(merged_df['Happiness Score_2016']),
              y0=min(merged_df['Happiness Score_2016']), y1=max(merged_df['Happiness Score_2016']),
              line=dict(color='Red', dash='dash'))
fig.show()

# %% [markdown]
# 3:Did any country experience a significant increase or decrease in happiness?

# %%
merged_df = df_15.merge(df_16, on='Country', suffixes=('_2015', '_2016')) \
                    .merge(df_17, on='Country', suffixes=('', '_2017')) \
                    .merge(df_18, on='Country', suffixes=('', '_2018')) \
                    .merge(df_19, on='Country', suffixes=('', '_2019'))


merged_df['Rank Change 2016-2017'] = merged_df['Happiness Rank_2016'] - merged_df['Happiness Rank']
merged_df['Score Change 2016-2017'] = merged_df['Happiness Score'] - merged_df['Happiness Score_2016']

merged_df['Rank Change 2017-2018'] = merged_df['Happiness Rank'] - merged_df['Happiness Rank']
merged_df['Score Change 2017-2018'] = merged_df['Happiness Score_2018'] - merged_df['Happiness Score']

merged_df['Rank Change 2018-2019'] = merged_df['Happiness Rank'] - merged_df['Happiness Rank']
merged_df['Score Change 2018-2019'] = merged_df['Happiness Score_2019'] - merged_df['Happiness Score']

# Visualize changes in scores over the years for each country
fig = px.line(merged_df, 
              x='Country', 
              y=['Happiness Score_2015', 'Happiness Score_2016', 'Happiness Score', 'Happiness Score_2018', 'Happiness Score_2019'],
              title='Happiness Score Changes from 2015 to 2019',
              labels={'value': 'Happiness Score', 'variable': 'Year'})

fig.show()

# %% [markdown]
# Bounce:Saudi Arabia's ranking changed in 2015, 2016, 2017, 2018 and 2019 ?

# %%
dataframes = [df_15, df_16, df_17, df_18, df_19]


saudi_arabia_ranks = [df['Happiness Rank'][df['Country'] == 'Saudi Arabia'].values[0] for df in dataframes]


fig = go.Figure(data=[go.Bar(x=['2015', '2016', '2017', '2018', '2019'],
                             y=saudi_arabia_ranks,
                             marker_color='skyblue')])

fig.update_layout(title='Saudi Arabia Ranking Over Time',
                  xaxis_title='Year',
                  yaxis_title='Saudi Arabia Rank')

fig.show()
